# %% [markdown]
# ## Implementation of a simple Actor-Critic algorithm
# ### Using Cartpole environment provided by gym

# %%
import sys
import torch  
import gym
import numpy as np  
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt
import pandas as pd

# %%
# neural network
class ActorCritic(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_size, learning_rate=3e-4):
        super(ActorCritic, self).__init__()

        # critic layers
        torch.manual_seed(1)
        self.num_actions = num_actions
        self.critic_linear1 = nn.Linear(num_inputs, hidden_size)
        self.critic_linear2 = nn.Linear(hidden_size, 1)

        #actor layers
        self.actor_linear1 = nn.Linear(num_inputs, hidden_size)
        self.actor_linear2 = nn.Linear(hidden_size, num_actions)
    
    def forward(self, state):
        torch.manual_seed(1)
        state = Variable(torch.from_numpy(state).float().unsqueeze(0)) # state to tensor
        value = F.relu(self.critic_linear1(state)) # go through first layer
        value = self.critic_linear2(value) # go through last layer
        
        policy_dist = F.relu(self.actor_linear1(state)) # go through first layer
        policy_dist = F.softmax(self.actor_linear2(policy_dist), dim=1) # go through last layer, and turn into probabilities

        return value, policy_dist # return value (given state) & action prob_dist (given state)

# %%
def take_steps(actor_critic, env, max_steps, entropy_term): 
    num_outputs = env.action_space.n
    action_space = np.arange(env.action_space.n)
    done = False
    state = env.reset()
    states, rewards, logprobs, values = [], [], [], []
    
    for step in range(max_steps):
        value, policy_dist = actor_critic.forward(state)
        value = value.detach().numpy()[0,0]
        dist = policy_dist.detach().numpy() 

        action = np.random.choice(num_outputs, p=np.squeeze(dist))
        log_prob = torch.log(policy_dist.squeeze(0)[action])
        entropy = -np.sum(np.mean(dist) * np.log(dist))
        new_state, reward, done, _ = env.step(action)
        
        states.append(state)
        rewards.append(reward)
        values.append(value)
        logprobs.append(log_prob)
        entropy_term += entropy
        state = new_state
        
        if done or step == max_steps-1:
            #save only the last next_value
            next_value, _ = actor_critic.forward(new_state)
            next_value = next_value.detach().numpy()[0,0]
            break # breaks if episode ended or max number of steps is achieved
                  #(can also chose to continue but need to save several next values then)

    
    return states, rewards, logprobs, values, next_value, entropy_term

# %%
def get_Qvals(Qvals, rewards, gamma, next_value):
    for t in reversed(range(len(rewards))):
        next_value = rewards[t] + gamma * next_value
        Qvals[t] = next_value
    return Qvals

# %%
def test_net(actor_critic, env, count=10):
    rewards = 0.0
    action_space = np.arange(env.action_space.n)
    for _ in range(count): # test for count episodes
        state = env.reset()
        while True:
            _, policy_dist = actor_critic.forward(state)
            dist = policy_dist.detach().numpy() 
            action = np.random.choice(action_space, p=np.squeeze(dist))
            state, reward, done, _ = env.step(action)
            rewards += reward
            if done:
                break
    return rewards / count # return average reward of the episodes

# %%
def a2c(env, hidden_size, learning_rate, gamma, max_steps, total_steps):
    all_rewards = []
    test_returns = []
    
    #initialize model and optimizer
    num_inputs = env.observation_space.shape[0]
    num_outputs = env.action_space.n
    actor_critic = ActorCritic(num_inputs, num_outputs, hidden_size) # can call predict(state)
    ac_optimizer = optim.Adam(actor_critic.parameters(), lr=learning_rate)
    
    #define others
    action_space = np.arange(env.action_space.n)
    entropy_term = 0 

    for idx in range(total_steps):
        #get some steps
        states, rewards, logprobs, values, next_value, entropy_term = take_steps(actor_critic, env, max_steps, entropy_term)
        
        #save and print progress
        all_rewards.append(sum(rewards))
        if idx % 10 == 0:
            test = test_net(actor_critic, env, 10)
            test_returns.append(test)
            print("step: ", idx," return: ", test)
            
        Qvals = np.zeros_like(values)
        Q = get_Qvals(Qvals, rewards, gamma, next_value)
        
        # convert to tensors
        values = torch.FloatTensor(values)
        Q = torch.FloatTensor(Q)
        logprobs = torch.stack(logprobs)
        
        #calculate Advantage
        A = Q - values
        
        #calculate loss for actor-critic
        actor_loss = (-logprobs * A).mean()
        critic_loss = 0.5 * A.pow(2).mean() # MSE
        ac_loss = (actor_loss + critic_loss) - 0.01 * entropy_term
        
        #update actor-critic parameters
        ac_optimizer.zero_grad()
        ac_loss.backward()
        ac_optimizer.step()  
    
    
    return all_rewards, test_returns

# %%
env = gym.make("CartPole-v0")
env.seed(0)
all_rewards, test_returns = a2c(env, hidden_size = 256, learning_rate = 3e-4, gamma = 0.99, max_steps = 200, total_steps = 1000)

smooth_rewards = pd.Series.rolling(pd.Series(all_rewards), 10).mean()
smooth_rewards = [elem for elem in smooth_rewards]

plt.plot(all_rewards)
plt.plot(smooth_rewards)
plt.ylabel("reward")
plt.xlabel("steps")
plt.show()

plt.plot(test_returns)
plt.ylabel("reward")
plt.xlabel("steps")
plt.show()
# Out:
# step:  0  return:  23.3
# step:  10  return:  19.1
# step:  20  return:  23.1
# step:  30  return:  25.4
# step:  40  return:  28.3
# step:  50  return:  28.2
# step:  60  return:  30.9
# step:  70  return:  31.4
# step:  80  return:  24.1
# step:  90  return:  29.4
# step:  100  return:  28.0
# step:  110  return:  28.0
# step:  120  return:  27.9
# step:  130  return:  29.9
# step:  140  return:  24.5
# step:  150  return:  33.0
# step:  160  return:  35.4
# step:  170  return:  28.4
# step:  180  return:  42.4
# step:  190  return:  32.5
# step:  200  return:  32.3
# step:  210  return:  41.1
# step:  220  return:  32.4
# step:  230  return:  36.4
# step:  240  return:  34.4
# step:  250  return:  37.2
# step:  260  return:  29.8
# step:  270  return:  38.0
# step:  280  return:  52.6
# step:  290  return:  45.2
# step:  300  return:  56.8
# step:  310  return:  38.5
# step:  320  return:  42.7
# step:  330  return:  69.0
# step:  340  return:  40.4
# step:  350  return:  40.3
# step:  360  return:  36.4
# step:  370  return:  47.0
# step:  380  return:  54.5
# step:  390  return:  42.1
# step:  400  return:  40.2
# step:  410  return:  38.3
# step:  420  return:  38.3
# step:  430  return:  46.9
# step:  440  return:  35.1
# step:  450  return:  50.7
# step:  460  return:  36.6
# step:  470  return:  52.7
# step:  480  return:  59.5
# step:  490  return:  55.0
# step:  500  return:  49.8
# step:  510  return:  59.1
# step:  520  return:  68.1
# step:  530  return:  43.2
# step:  540  return:  43.9
# step:  550  return:  58.2
# step:  560  return:  54.3
# step:  570  return:  59.2
# step:  580  return:  55.4
# step:  590  return:  60.6
# step:  600  return:  65.7
# step:  610  return:  60.3
# step:  620  return:  75.4
# step:  630  return:  66.8
# step:  640  return:  85.7
# step:  650  return:  80.7
# step:  660  return:  76.7
# step:  670  return:  82.0
# step:  680  return:  79.7
# step:  690  return:  61.9
# step:  700  return:  87.2
# step:  710  return:  56.8
# step:  720  return:  85.6
# step:  730  return:  94.3
# step:  740  return:  69.2
# step:  750  return:  104.6
# step:  760  return:  92.2
# step:  770  return:  104.0
# step:  780  return:  111.4
# step:  790  return:  82.2
# step:  800  return:  99.0
# step:  810  return:  121.2
# step:  820  return:  104.3
# step:  830  return:  85.2
# step:  840  return:  122.0
# step:  850  return:  108.6
# step:  860  return:  126.3
# step:  870  return:  71.2
# step:  880  return:  122.5
# step:  890  return:  125.3
# step:  900  return:  143.0
# step:  910  return:  118.8
# step:  920  return:  137.2
# step:  930  return:  99.2
# step:  940  return:  101.8
# step:  950  return:  133.0
# step:  960  return:  120.6
# step:  970  return:  113.7
# step:  980  return:  122.9
# step:  990  return:  156.9

# %%
env = gym.make("CartPole-v0")
env.seed(0)
all_rewards, test_returns = a2c(env, hidden_size = 256, learning_rate = 3e-4, gamma = 0.99, max_steps = 50, total_steps = 2000)

smooth_rewards = pd.Series.rolling(pd.Series(all_rewards), 10).mean()
smooth_rewards = [elem for elem in smooth_rewards]

plt.plot(all_rewards)
plt.plot(smooth_rewards)
plt.ylabel("reward")
plt.xlabel("steps")
plt.show()

plt.plot(test_returns)
plt.ylabel("reward")
plt.xlabel("steps")
plt.show()
# Out:
# step:  0  return:  20.0
# step:  10  return:  21.6
# step:  20  return:  20.3
# step:  30  return:  25.0
# step:  40  return:  22.1
# step:  50  return:  20.6
# step:  60  return:  32.8
# step:  70  return:  25.7
# step:  80  return:  20.5
# step:  90  return:  20.8
# step:  100  return:  22.2
# step:  110  return:  24.9
# step:  120  return:  23.6
# step:  130  return:  32.7
# step:  140  return:  30.8
# step:  150  return:  30.8
# step:  160  return:  19.1
# step:  170  return:  27.1
# step:  180  return:  25.9
# step:  190  return:  24.4
# step:  200  return:  28.6
# step:  210  return:  22.0
# step:  220  return:  29.2
# step:  230  return:  24.1
# step:  240  return:  28.6
# step:  250  return:  27.0
# step:  260  return:  24.3
# step:  270  return:  25.0
# step:  280  return:  31.5
# step:  290  return:  33.7
# step:  300  return:  27.7
# step:  310  return:  30.2
# step:  320  return:  37.7
# step:  330  return:  24.9
# step:  340  return:  41.4
# step:  350  return:  27.4
# step:  360  return:  44.0
# step:  370  return:  38.5
# step:  380  return:  32.4
# step:  390  return:  33.5
# step:  400  return:  35.7
# step:  410  return:  40.0
# step:  420  return:  44.9
# step:  430  return:  40.2
# step:  440  return:  60.5
# step:  450  return:  66.6
# step:  460  return:  42.7
# step:  470  return:  43.7
# step:  480  return:  47.5
# step:  490  return:  57.9
# step:  500  return:  48.7
# step:  510  return:  58.3
# step:  520  return:  44.6
# step:  530  return:  50.1
# step:  540  return:  41.8
# step:  550  return:  56.6
# step:  560  return:  42.8
# step:  570  return:  68.8
# step:  580  return:  47.0
# step:  590  return:  51.7
# step:  600  return:  33.4
# step:  610  return:  47.8
# step:  620  return:  62.3
# step:  630  return:  40.0
# step:  640  return:  42.3
# step:  650  return:  37.7
# step:  660  return:  45.5
# step:  670  return:  54.8
# step:  680  return:  56.2
# step:  690  return:  46.0
# step:  700  return:  43.5
# step:  710  return:  50.2
# step:  720  return:  65.4
# step:  730  return:  55.2
# step:  740  return:  68.9
# step:  750  return:  50.5
# step:  760  return:  62.2
# step:  770  return:  57.7
# step:  780  return:  79.6
# step:  790  return:  82.7
# step:  800  return:  52.1
# step:  810  return:  62.3
# step:  820  return:  68.5
# step:  830  return:  75.8
# step:  840  return:  63.0
# step:  850  return:  69.6
# step:  860  return:  64.4
# step:  870  return:  80.9
# step:  880  return:  63.3
# step:  890  return:  67.8
# step:  900  return:  55.3
# step:  910  return:  47.7
# step:  920  return:  48.0
# step:  930  return:  58.3
# step:  940  return:  40.9
# step:  950  return:  72.9
# step:  960  return:  65.8
# step:  970  return:  52.5
# step:  980  return:  56.2
# step:  990  return:  68.5
# step:  1000  return:  63.5
# step:  1010  return:  79.5
# step:  1020  return:  61.8
# step:  1030  return:  52.9
# step:  1040  return:  49.7
# step:  1050  return:  50.6
# step:  1060  return:  62.2
# step:  1070  return:  68.9
# step:  1080  return:  56.8
# step:  1090  return:  48.7
# step:  1100  return:  84.2
# step:  1110  return:  41.1
# step:  1120  return:  56.8
# step:  1130  return:  58.1
# step:  1140  return:  38.1
# step:  1150  return:  55.0
# step:  1160  return:  66.3
# step:  1170  return:  55.2
# step:  1180  return:  64.1
# step:  1190  return:  43.4
# step:  1200  return:  51.3
# step:  1210  return:  63.7
# step:  1220  return:  62.5
# step:  1230  return:  109.0
# step:  1240  return:  81.8
# step:  1250  return:  104.7
# step:  1260  return:  84.0
# step:  1270  return:  91.3
# step:  1280  return:  78.2
# step:  1290  return:  100.1
# step:  1300  return:  87.3
# step:  1310  return:  102.1
# step:  1320  return:  65.5
# step:  1330  return:  116.3
# step:  1340  return:  95.7
# step:  1350  return:  107.4
# step:  1360  return:  86.4
# step:  1370  return:  67.4
# step:  1380  return:  79.2
# step:  1390  return:  110.6
# step:  1400  return:  94.4
# step:  1410  return:  130.9
# step:  1420  return:  102.2
# step:  1430  return:  88.0
# step:  1440  return:  109.8
# step:  1450  return:  117.2
# step:  1460  return:  107.6
# step:  1470  return:  84.3
# step:  1480  return:  96.3
# step:  1490  return:  93.7
# step:  1500  return:  92.1
# step:  1510  return:  89.7
# step:  1520  return:  67.4
# step:  1530  return:  76.7
# step:  1540  return:  71.0
# step:  1550  return:  102.4
# step:  1560  return:  79.7
# step:  1570  return:  92.1
# step:  1580  return:  87.1
# step:  1590  return:  91.8
# step:  1600  return:  84.7
# step:  1610  return:  104.6
# step:  1620  return:  92.8
# step:  1630  return:  67.2
# step:  1640  return:  120.3
# step:  1650  return:  111.8
# step:  1660  return:  116.6
# step:  1670  return:  73.1
# step:  1680  return:  86.7
# step:  1690  return:  76.9
# step:  1700  return:  81.7
# step:  1710  return:  86.1
# step:  1720  return:  105.1
# step:  1730  return:  87.5
# step:  1740  return:  78.8
# step:  1750  return:  90.0
# step:  1760  return:  66.6
# step:  1770  return:  84.4
# step:  1780  return:  93.7
# step:  1790  return:  54.8
# step:  1800  return:  82.6
# step:  1810  return:  72.0
# step:  1820  return:  77.4
# step:  1830  return:  97.2
# step:  1840  return:  76.2
# step:  1850  return:  85.6
# step:  1860  return:  136.5
# step:  1870  return:  111.1
# step:  1880  return:  122.5
# step:  1890  return:  123.6
# step:  1900  return:  124.8
# step:  1910  return:  119.0
# step:  1920  return:  142.1
# step:  1930  return:  94.8
# step:  1940  return:  172.4
# step:  1950  return:  127.1
# step:  1960  return:  118.8
# step:  1970  return:  108.0
# step:  1980  return:  110.1
# step:  1990  return:  88.7

# %%
env = gym.make("CartPole-v0")
env.seed(0)
all_rewards, test_returns = a2c(env, hidden_size = 256, learning_rate = 3e-4, gamma = 0.99, max_steps = 150, total_steps = 2000)

smooth_rewards = pd.Series.rolling(pd.Series(all_rewards), 10).mean()
smooth_rewards = [elem for elem in smooth_rewards]

plt.plot(all_rewards)
plt.plot(smooth_rewards)
plt.ylabel("reward")
plt.xlabel("steps")
plt.show()

plt.plot(test_returns)
plt.ylabel("reward")
plt.xlabel("steps")
plt.show()
# Out:
# step:  0  return:  19.1
# step:  10  return:  21.0
# step:  20  return:  21.0
# step:  30  return:  27.2
# step:  40  return:  25.7
# step:  50  return:  20.5
# step:  60  return:  24.5
# step:  70  return:  19.4
# step:  80  return:  21.9
# step:  90  return:  16.9
# step:  100  return:  21.4
# step:  110  return:  23.8
# step:  120  return:  25.2
# step:  130  return:  32.5
# step:  140  return:  23.7
# step:  150  return:  33.8
# step:  160  return:  42.2
# step:  170  return:  38.9
# step:  180  return:  35.3
# step:  190  return:  31.0
# step:  200  return:  29.9
# step:  210  return:  33.8
# step:  220  return:  34.0
# step:  230  return:  28.9
# step:  240  return:  45.2
# step:  250  return:  32.9
# step:  260  return:  39.7
# step:  270  return:  33.2
# step:  280  return:  41.4
# step:  290  return:  40.3
# step:  300  return:  40.6
# step:  310  return:  38.5
# step:  320  return:  35.7
# step:  330  return:  37.3
# step:  340  return:  67.6
# step:  350  return:  44.7
# step:  360  return:  60.4
# step:  370  return:  49.8
# step:  380  return:  41.6
# step:  390  return:  35.2
# step:  400  return:  60.7
# step:  410  return:  43.7
# step:  420  return:  45.5
# step:  430  return:  46.0
# step:  440  return:  50.5
# step:  450  return:  41.0
# step:  460  return:  58.1
# step:  470  return:  59.7
# step:  480  return:  55.1
# step:  490  return:  52.2
# step:  500  return:  56.7
# step:  510  return:  78.6
# step:  520  return:  53.4
# step:  530  return:  41.5
# step:  540  return:  42.7
# step:  550  return:  42.8
# step:  560  return:  62.2
# step:  570  return:  57.1
# step:  580  return:  54.9
# step:  590  return:  54.8
# step:  600  return:  88.4
# step:  610  return:  87.9
# step:  620  return:  59.2
# step:  630  return:  52.6
# step:  640  return:  76.2
# step:  650  return:  70.8
# step:  660  return:  52.3
# step:  670  return:  72.1
# step:  680  return:  95.4
# step:  690  return:  77.3
# step:  700  return:  69.9
# step:  710  return:  96.9
# step:  720  return:  62.7
# step:  730  return:  96.0
# step:  740  return:  78.6
# step:  750  return:  101.2
# step:  760  return:  77.1
# step:  770  return:  74.1
# step:  780  return:  126.3
# step:  790  return:  117.0
# step:  800  return:  94.9
# step:  810  return:  115.9
# step:  820  return:  76.9
# step:  830  return:  111.9
# step:  840  return:  125.8
# step:  850  return:  103.4
# step:  860  return:  134.4
# step:  870  return:  107.7
# step:  880  return:  107.8
# step:  890  return:  135.3
# step:  900  return:  95.0
# step:  910  return:  122.7
# step:  920  return:  104.8
# step:  930  return:  119.9
# step:  940  return:  97.2
# step:  950  return:  135.2
# step:  960  return:  118.6
# step:  970  return:  138.6
# step:  980  return:  114.0
# step:  990  return:  143.4
# step:  1000  return:  130.8
# step:  1010  return:  108.6
# step:  1020  return:  107.1
# step:  1030  return:  97.3
# step:  1040  return:  139.4
# step:  1050  return:  127.5
# step:  1060  return:  114.5
# step:  1070  return:  137.7
# step:  1080  return:  150.7
# step:  1090  return:  151.3
# step:  1100  return:  132.6
# step:  1110  return:  142.7
# step:  1120  return:  143.5
# step:  1130  return:  124.7
# step:  1140  return:  118.5
# step:  1150  return:  112.6
# step:  1160  return:  126.8
# step:  1170  return:  152.2
# step:  1180  return:  119.8
# step:  1190  return:  150.9
# step:  1200  return:  157.4
# step:  1210  return:  149.8
# step:  1220  return:  165.3
# step:  1230  return:  190.7
# step:  1240  return:  152.2
# step:  1250  return:  158.0
# step:  1260  return:  180.6
# step:  1270  return:  151.8
# step:  1280  return:  190.3
# step:  1290  return:  153.6
# step:  1300  return:  127.3
# step:  1310  return:  110.3
# step:  1320  return:  138.7
# step:  1330  return:  136.4
# step:  1340  return:  149.7
# step:  1350  return:  135.1
# step:  1360  return:  157.9
# step:  1370  return:  157.0
# step:  1380  return:  150.0
# step:  1390  return:  169.8
# step:  1400  return:  131.5
# step:  1410  return:  175.8
# step:  1420  return:  156.6
# step:  1430  return:  174.1
# step:  1440  return:  163.3
# step:  1450  return:  167.0
# step:  1460  return:  157.2
# step:  1470  return:  140.8
# step:  1480  return:  88.3
# step:  1490  return:  159.2
# step:  1500  return:  157.9
# step:  1510  return:  137.7
# step:  1520  return:  190.4
# step:  1530  return:  144.0
# step:  1540  return:  169.5
# step:  1550  return:  164.4
# step:  1560  return:  159.0
# step:  1570  return:  150.2
# step:  1580  return:  176.4
# step:  1590  return:  128.8
# step:  1600  return:  157.0
# step:  1610  return:  148.4
# step:  1620  return:  155.0
# step:  1630  return:  175.8
# step:  1640  return:  179.0
# step:  1650  return:  173.3
# step:  1660  return:  174.7
# step:  1670  return:  168.8
# step:  1680  return:  165.6
# step:  1690  return:  113.8
# step:  1700  return:  147.1
# step:  1710  return:  168.9
# step:  1720  return:  146.5
# step:  1730  return:  157.9
# step:  1740  return:  166.5
# step:  1750  return:  163.9
# step:  1760  return:  169.3
# step:  1770  return:  152.4
# step:  1780  return:  167.1
# step:  1790  return:  186.2
# step:  1800  return:  178.2
# step:  1810  return:  150.3
# step:  1820  return:  160.6
# step:  1830  return:  186.8
# step:  1840  return:  199.3
# step:  1850  return:  180.1
# step:  1860  return:  187.4
# step:  1870  return:  194.4
# step:  1880  return:  183.3
# step:  1890  return:  162.6
# step:  1900  return:  179.2
# step:  1910  return:  186.4
# step:  1920  return:  182.9
# step:  1930  return:  150.3
# step:  1940  return:  183.7
# step:  1950  return:  173.0
# step:  1960  return:  175.6
# step:  1970  return:  146.4
# step:  1980  return:  147.6
# step:  1990  return:  149.2
